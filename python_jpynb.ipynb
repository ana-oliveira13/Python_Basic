# %% [markdown]
# <a href="https://colab.research.google.com/github/ana-oliveira13/Python_Basic/blob/main/python_jpynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Everything can change if you learn to change'')

Everything can change if you learn to change

# %% [markdown]
#      solution =
